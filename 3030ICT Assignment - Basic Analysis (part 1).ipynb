# %%
#Import necessary librarys for this section
#Open first data set - 5 core reviews for electronics - by converting JSON file to pandas dataframe format 

import pandas as pd
import gzip
from datetime import datetime

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('reviews_Electronics_5.json.gz')
df.head()
# Out:
#        reviewerID        asin              reviewerName   helpful  \
# 0   AO94DHGC771SJ  0528881469                   amazdnu    [0, 0]
# 1   AMO214LNFCEI4  0528881469           Amazon Customer  [12, 15]
# 2  A3N7T0DY83Y4IG  0528881469             C. A. Freeman  [43, 45]
# 3  A1H8PY3QHMQQA0  0528881469  Dave M. Shaw "mack dave"   [9, 10]
# 4  A24EV6RXELQZ63  0528881469               Wayne Smith    [0, 0]
#
#                                           reviewText  overall  \
# 0  We got this GPS for my husband who is an (OTR)...      5.0
# 1  I'm a professional OTR truck driver, and I bou...      1.0
# 2  Well, what can I say.  I've had this unit in m...      3.0
# 3  Not going to write a long review, even thought...      2.0
# 4  I've had mine for a year and here's what we go...      1.0
#
#                                   summary  unixReviewTime   reviewTime
# 0                         Gotta have GPS!      1370131200   06 2, 2013
# 1                       Very Disappointed      1290643200  11 25, 2010
# 2                          1st impression      1283990400   09 9, 2010
# 3                 Great grafics, POOR GPS      1290556800  11 24, 2010
# 4  Major issues, only excuses for support      1317254400  09 29, 2011

# %%
#Look at the length of the total dataset 
print(len(df))
# Out:
# 1689188

# %%
#Analyse the format of all data types 
#Most are labelled as objects apart from the rating and Time which are numerical
#Time needs to be changed to an appropriate format 
df.dtypes
# Out:
# reviewerID         object
# asin               object
# reviewerName       object
# helpful            object
# reviewText         object
# overall           float64
# summary            object
# unixReviewTime      int64
# reviewTime         object
# dtype: object

# %%
#changing the Time format to pandas DateTime
df['ReviewTime'] = pd.to_datetime(df['unixReviewTime'],unit='s')

# %%
#A new column called ReviewTime was added to the dataframe with correct format
df.dtypes
# Out:
# reviewerID                object
# asin                      object
# reviewerName              object
# helpful                   object
# reviewText                object
# overall                  float64
# summary                   object
# unixReviewTime             int64
# reviewTime                object
# ReviewTime        datetime64[ns]
# dtype: object

# %%
#The other two columms with incorrect format for Date/Time were removed from the dataframe 
df.drop(['reviewTime', 'unixReviewTime'], axis="columns", inplace =True)
df.head()
# Out:
#        reviewerID        asin              reviewerName   helpful  \
# 0   AO94DHGC771SJ  0528881469                   amazdnu    [0, 0]
# 1   AMO214LNFCEI4  0528881469           Amazon Customer  [12, 15]
# 2  A3N7T0DY83Y4IG  0528881469             C. A. Freeman  [43, 45]
# 3  A1H8PY3QHMQQA0  0528881469  Dave M. Shaw "mack dave"   [9, 10]
# 4  A24EV6RXELQZ63  0528881469               Wayne Smith    [0, 0]
#
#                                           reviewText  overall  \
# 0  We got this GPS for my husband who is an (OTR)...      5.0
# 1  I'm a professional OTR truck driver, and I bou...      1.0
# 2  Well, what can I say.  I've had this unit in m...      3.0
# 3  Not going to write a long review, even thought...      2.0
# 4  I've had mine for a year and here's what we go...      1.0
#
#                                   summary ReviewTime
# 0                         Gotta have GPS! 2013-06-02
# 1                       Very Disappointed 2010-11-25
# 2                          1st impression 2010-09-09
# 3                 Great grafics, POOR GPS 2010-11-24
# 4  Major issues, only excuses for support 2011-09-29

# %%
#We want to keep duplicate rows as there are multiple of the same products but with different ratings.
#To make analysis easier we need to change the product name (asin) to the actual product name
#To change product name we need the metadata for the ratings and merge tables together

# %%
#Open up next file which contains the metadata for the electronics category


def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

metadata = getDF('meta_Electronics.json.gz')
metadata.head()
# Out:
#          asin                                              imUrl  \
# 0  0132793040  http://ecx.images-amazon.com/images/I/31JIPhp%...
# 1  0321732944  http://ecx.images-amazon.com/images/I/31uogm6Y...
# 2  0439886341  http://ecx.images-amazon.com/images/I/51k0qa8f...
# 3  0511189877  http://ecx.images-amazon.com/images/I/41HaAhbv...
# 4  0528881469  http://ecx.images-amazon.com/images/I/51FnRkJq...
#
#                                          description  \
# 0  The Kelby Training DVD Mastering Blend Modes i...
# 1                                                NaN
# 2                    Digital Organizer and Messenger
# 3  The CLIKR-5 UR5U-8780L remote control is desig...
# 4  Like its award-winning predecessor, the Intell...
#
#                                           categories  \
# 0  [[Electronics, Computers & Accessories, Cables...
# 1  [[Electronics, Computers & Accessories, Cables...
# 2  [[Electronics, Computers & Accessories, PDAs, ...
# 3  [[Electronics, Accessories & Supplies, Audio &...
# 4  [[Electronics, GPS & Navigation, Vehicle GPS, ...
#
#                                                title   price  \
# 0  Kelby Training DVD: Mastering Blend Modes in A...     NaN
# 1  Kelby Training DVD: Adobe Photoshop CS5 Crash ...     NaN
# 2                    Digital Organizer and Messenger    8.15
# 3  CLIKR-5 Time Warner Cable Remote Control UR5U-...   23.36
# 4  Rand McNally 528881469 7-inch Intelliroute TND...  299.99
#
#                  salesRank                                            related  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2  {'Electronics': 144944}  {'also_viewed': ['0545016266', 'B009ECM8QY', '...
# 3                      NaN  {'also_viewed': ['B001KC08A4', 'B00KUL8O0W', '...
# 4                      NaN  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...
#
#   brand
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
#Merge both dataframes together using the column 'asin' as a common key from both 
rating_data = pd.merge(df, metadata, how="left", on="asin")
rating_data.head()
# Out:
#        reviewerID        asin              reviewerName   helpful  \
# 0   AO94DHGC771SJ  0528881469                   amazdnu    [0, 0]
# 1   AMO214LNFCEI4  0528881469           Amazon Customer  [12, 15]
# 2  A3N7T0DY83Y4IG  0528881469             C. A. Freeman  [43, 45]
# 3  A1H8PY3QHMQQA0  0528881469  Dave M. Shaw "mack dave"   [9, 10]
# 4  A24EV6RXELQZ63  0528881469               Wayne Smith    [0, 0]
#
#                                           reviewText  overall  \
# 0  We got this GPS for my husband who is an (OTR)...      5.0
# 1  I'm a professional OTR truck driver, and I bou...      1.0
# 2  Well, what can I say.  I've had this unit in m...      3.0
# 3  Not going to write a long review, even thought...      2.0
# 4  I've had mine for a year and here's what we go...      1.0
#
#                                   summary ReviewTime  \
# 0                         Gotta have GPS! 2013-06-02
# 1                       Very Disappointed 2010-11-25
# 2                          1st impression 2010-09-09
# 3                 Great grafics, POOR GPS 2010-11-24
# 4  Major issues, only excuses for support 2011-09-29
#
#                                                imUrl  \
# 0  http://ecx.images-amazon.com/images/I/51FnRkJq...
# 1  http://ecx.images-amazon.com/images/I/51FnRkJq...
# 2  http://ecx.images-amazon.com/images/I/51FnRkJq...
# 3  http://ecx.images-amazon.com/images/I/51FnRkJq...
# 4  http://ecx.images-amazon.com/images/I/51FnRkJq...
#
#                                          description  \
# 0  Like its award-winning predecessor, the Intell...
# 1  Like its award-winning predecessor, the Intell...
# 2  Like its award-winning predecessor, the Intell...
# 3  Like its award-winning predecessor, the Intell...
# 4  Like its award-winning predecessor, the Intell...
#
#                                           categories  \
# 0  [[Electronics, GPS & Navigation, Vehicle GPS, ...
# 1  [[Electronics, GPS & Navigation, Vehicle GPS, ...
# 2  [[Electronics, GPS & Navigation, Vehicle GPS, ...
# 3  [[Electronics, GPS & Navigation, Vehicle GPS, ...
# 4  [[Electronics, GPS & Navigation, Vehicle GPS, ...
#
#                                                title   price salesRank  \
# 0  Rand McNally 528881469 7-inch Intelliroute TND...  299.99       NaN
# 1  Rand McNally 528881469 7-inch Intelliroute TND...  299.99       NaN
# 2  Rand McNally 528881469 7-inch Intelliroute TND...  299.99       NaN
# 3  Rand McNally 528881469 7-inch Intelliroute TND...  299.99       NaN
# 4  Rand McNally 528881469 7-inch Intelliroute TND...  299.99       NaN
#
#                                              related brand
# 0  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...   NaN
# 1  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...   NaN
# 2  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...   NaN
# 3  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...   NaN
# 4  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...   NaN

# %%
#Visualise if any of the columns contain null values
rating_data.isnull().sum()
# Out:
# reviewerID           0
# asin                 0
# reviewerName     24730
# helpful              0
# reviewText           0
# overall              0
# summary              0
# ReviewTime           0
# imUrl             1213
# description      33677
# categories           0
# title            45502
# price            49306
# salesRank       879118
# related          27046
# brand           734937
# dtype: int64

# %%
#Drop all rows that contain null values as they create inaccuracy in data reliance 
rating_data = rating_data.dropna()

# %%
#Double checking the dataset contains no null values 
rating_data.isnull().sum()
# Out:
# reviewerID      0
# asin            0
# reviewerName    0
# helpful         0
# reviewText      0
# overall         0
# summary         0
# ReviewTime      0
# imUrl           0
# description     0
# categories      0
# title           0
# price           0
# salesRank       0
# related         0
# brand           0
# dtype: int64

# %%
#Visualising all formats for merge data set
rating_data.dtypes
# Out:
# reviewerID              object
# asin                    object
# reviewerName            object
# helpful                 object
# reviewText              object
# overall                float64
# summary                 object
# ReviewTime      datetime64[ns]
# imUrl                   object
# description             object
# categories              object
# title                   object
# price                  float64
# salesRank               object
# related                 object
# brand                   object
# dtype: object

# %%
#Some columns are not necessary for the analysis and hence removed to make the data easier to work with 
rating_data.drop(['imUrl', 'reviewerName', 'salesRank'], axis="columns", inplace =True)
rating_data.head()
# Out:
#         reviewerID        asin helpful  \
# 19  A2IDCSC6NVONIZ  0972683275  [1, 1]
# 20  A1EDI0X3GI1SK7  0972683275  [0, 1]
# 21  A3BMUBUC1N77U8  0972683275  [0, 0]
# 22   AVRFGGCCCR6QU  0972683275  [3, 4]
# 23  A3UOSOCRKS3WIH  0972683275  [0, 0]
#
#                                            reviewText  overall  \
# 19  This mount is just what I needed.  It is stron...      5.0
# 20  Great deal, easy to mount and it appears to be...      5.0
# 21  This mount works really well once you get it u...      4.0
# 22  This wall mount does everything it's supposed ...      4.0
# 23  for the price you just cant beat this item. I ...      5.0
#
#                                 summary ReviewTime  \
# 19                              Perfect 2013-04-30
# 20                       32 In TV Mount 2011-12-16
# 21  Pretty simple, but definitely good! 2013-11-23
# 22               Fairly good wall mount 2010-08-30
# 23                        Cant Beat it! 2013-05-12
#
#                                           description  \
# 19  The VideoSecu TV mount is a mounting solution ...
# 20  The VideoSecu TV mount is a mounting solution ...
# 21  The VideoSecu TV mount is a mounting solution ...
# 22  The VideoSecu TV mount is a mounting solution ...
# 23  The VideoSecu TV mount is a mounting solution ...
#
#                                            categories  \
# 19  [[Electronics, Accessories & Supplies, Audio &...
# 20  [[Electronics, Accessories & Supplies, Audio &...
# 21  [[Electronics, Accessories & Supplies, Audio &...
# 22  [[Electronics, Accessories & Supplies, Audio &...
# 23  [[Electronics, Accessories & Supplies, Audio &...
#
#                                                 title  price  \
# 19  VideoSecu 24&quot; Long Arm TV Wall Mount Low ...  29.99
# 20  VideoSecu 24&quot; Long Arm TV Wall Mount Low ...  29.99
# 21  VideoSecu 24&quot; Long Arm TV Wall Mount Low ...  29.99
# 22  VideoSecu 24&quot; Long Arm TV Wall Mount Low ...  29.99
# 23  VideoSecu 24&quot; Long Arm TV Wall Mount Low ...  29.99
#
#                                               related      brand
# 19  {'also_bought': ['B000X3KOD2', 'B0074FGR74', '...  VideoSecu
# 20  {'also_bought': ['B000X3KOD2', 'B0074FGR74', '...  VideoSecu
# 21  {'also_bought': ['B000X3KOD2', 'B0074FGR74', '...  VideoSecu
# 22  {'also_bought': ['B000X3KOD2', 'B0074FGR74', '...  VideoSecu
# 23  {'also_bought': ['B000X3KOD2', 'B0074FGR74', '...  VideoSecu

# %%
#Final length of the data 
print(len(rating_data))
# Out:
# 517687

# %%
#Saving dataframe to csv file for part two of the assignment 
rating_data.to_csv(r'C:\Users\emjha\3030ICT.data.csv', index=False)
